# %%
import seaborn as sns

iris_sns=sns.load_dataset("iris")

# %%
sns.histplot(data=iris_sns,x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=iris_sns,x='petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=iris_sns,x='petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.kdeplot(data=iris_sns,x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=iris_sns,x='petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(data=iris_sns,x='petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>
