# %%
import numpy as np
import matplotlib.pyplot as plt

a_array=np.random.uniform(0,1,1000)

fig,ax=plt.subplots(figsize=(8,8))


ax.hist(a_array,10,density=True)
# Out:
# (array([0.93142188, 1.07163592, 0.94143716, 0.96146774, 1.08165121,
#         0.99151361, 1.08165121, 1.0015289 , 1.01154419, 0.94143716]),
#  array([4.19141868e-04, 1.00266485e-01, 2.00113829e-01, 2.99961173e-01,
#         3.99808516e-01, 4.99655860e-01, 5.99503203e-01, 6.99350547e-01,
#         7.99197890e-01, 8.99045234e-01, 9.98892577e-01]),
#  <BarContainer object of 10 artists>)
