# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
p = plt.rcParams  # 获取默认绘图参数
p["font.weight"] = "light"  # 设置字体粗细为 light
p["ytick.minor.visible"] = True  # 显示 y 轴的小刻度
p["xtick.minor.visible"] = True  # 显示 x 轴的小刻度
p["axes.grid"] = True  # 启用坐标轴网格
p["grid.color"] = "0.5"  # 设置网格颜色为灰色
p["grid.linewidth"] = 0.5  # 设置网格线宽度

# %%
def plot_stem(df,column):
    #第一个方法计算每个值出现次数(降序),返回Series,第二个转为df,第三个变为升序
    pmf_df = df[column].value_counts().to_frame().sort_index() / len(df)
    fig,ax = plt.subplots()
    #之前的数据,变为df后,series的记数的columnname变为'count'
    #.index取出索引,之前的不重复的值,类型看存进来是什么类型
    centroid = np.sum(pmf_df['count'] * pmf_df.index) #计算均值
    plt.stem(pmf_df.index,pmf_df['count'].astype(float))
    plt.vlines(centroid, 0, 0.3, colors='r', linestyles='--') # 绘制质心的垂线
    plt.ylim(0, 0.3) # 设置y轴范围
    plt.xlim(-5, 40) # 设置x轴范围
    plt.ylabel('Probability, PMF') # 设置y轴标签
    plt.title(column + '; average = ' + '{0:.2f}'.format(centroid)) # 设置标题

# %%
def plot_contour(XX1,XX2,df,column,XX1_fine,XX2_fine,YY):
    XX1_ = XX1.ravel()
    XX2_ = XX2.ravel()
    #sort进行排序,升序排序
    levels = np.sort(df[column].unique()) #unique去重
    print(list(levels))
    fig,ax = plt.subplots()
    plt.scatter(XX1_,XX2_)
    CS = plt.contour(XX1_fine,XX2_fine,YY,levels = levels,cmap = 'rainbow')
    ax.clabel(CS,inline = True,fontsize = 12,fmt = '%.2f')
    ax.set_aspect('equal',adjustable = 'box')
    plt.grid(True)
    plt.xlim(1 - 0.5, 6 + 0.5) # 设置x轴范围
    plt.ylim(1 - 0.5, 6 + 0.5) # 设置y轴范围
    ax.spines['top'].set_visible(False) # 隐藏顶部边框
    ax.spines['right'].set_visible(False) # 隐藏右侧边框
    ax.spines['bottom'].set_visible(False) # 隐藏底部边框
    ax.spines['left'].set_visible(False) # 隐藏左侧边框
    ax.tick_params(axis="y", direction='in', length=8) # 设置y轴刻度方向
    ax.tick_params(axis="x", direction='in', length=8) # 设置x轴刻度方向
    plt.xlabel('$X_1$') # 设置x轴标签
    plt.ylabel('$X_2$') # 设置y轴标签
    plt.title(column) # 设置标题

# %%
X1_array = np.arange(1,6+1)
X2_array = np.arange(1,6+1)

X1_fine_array = np.linspace(0.5,6.5,100)
X2_fine_array = np.linspace(0.5,6.5,100)

XX1,XX2 = np.meshgrid(X1_array,X2_array)
#fine是精细的意思
XX1_fine,XX2_fine = np.meshgrid(X1_fine_array,X2_fine_array)

XX1_ = XX1.ravel()
XX2_ = XX2.ravel()

df = pd.DataFrame(np.column_stack((XX1_,XX2_)),columns =['X1','X2'])

# %%
YY_X1_only = XX1_fine
plot_contour(XX1,XX2,df,'X1',XX1_fine,XX2_fine,YY_X1_only)
# Out:
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]

# %%
plot_stem(df,'X1')

# %%
df['X1_sq'] = df['X1'] ** 2
YY_X1_sq = XX1_fine**2
plot_contour(XX1,XX2,df,'X1_sq',XX1_fine,XX2_fine,YY_X1_sq)
# Out:
# [np.int64(1), np.int64(4), np.int64(9), np.int64(16), np.int64(25), np.int64(36)]

# %%
plot_stem(df,'X1_sq')

# %%
df['sum'] = (df['X1'] + df['X2'])
YY_sum = XX1_fine + XX2_fine
plot_contour(XX1,XX2,df,'sum',XX1_fine,XX2_fine,YY_sum)
# Out:
# [np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12)]

# %%
plot_stem(df,'sum')

# %%
df['mean'] = (df['X1'] + df['X2']) / 2
YY_mean = (XX1_fine + XX2_fine) / 2
plot_contour(XX1,XX2,df,'mean',XX1_fine,XX2_fine,YY_mean)
# Out:
# [np.float64(1.0), np.float64(1.5), np.float64(2.0), np.float64(2.5), np.float64(3.0), np.float64(3.5), np.float64(4.0), np.float64(4.5), np.float64(5.0), np.float64(5.5), np.float64(6.0)]

# %%
plot_stem(df,'mean')

# %%
df['mean_centered'] = (df['X1'] + df['X2'] - 7) / 2
YY_mean_centered = (XX1_fine + XX2_fine - 7) / 2
plot_contour(XX1,XX2,df,'mean_centered',XX1_fine,XX2_fine,YY_mean_centered)
# Out:
# [np.float64(-2.5), np.float64(-2.0), np.float64(-1.5), np.float64(-1.0), np.float64(-0.5), np.float64(0.0), np.float64(0.5), np.float64(1.0), np.float64(1.5), np.float64(2.0), np.float64(2.5)]

# %%
plot_stem(df,'mean_centered')

# %%
df['product'] = df['X1'] * df['X2']
YY_product = XX1_fine * XX2_fine
plot_contour(XX1,XX2,df,'product',XX1_fine,XX2_fine,YY_product)
# Out:
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(8), np.int64(9), np.int64(10), np.int64(12), np.int64(15), np.int64(16), np.int64(18), np.int64(20), np.int64(24), np.int64(25), np.int64(30), np.int64(36)]

# %%
plot_stem(df,'product')

# %%
df['devision'] = df['X1'] / df['X2']
YY_devision = XX1_fine / XX2_fine
plot_contour(XX1,XX2,df,'devision',XX1_fine,XX2_fine,YY_devision)
# Out:
# [np.float64(0.16666666666666666), np.float64(0.2), np.float64(0.25), np.float64(0.3333333333333333), np.float64(0.4), np.float64(0.5), np.float64(0.6), np.float64(0.6666666666666666), np.float64(0.75), np.float64(0.8), np.float64(0.8333333333333334), np.float64(1.0), np.float64(1.2), np.float64(1.25), np.float64(1.3333333333333333), np.float64(1.5), np.float64(1.6666666666666667), np.float64(2.0), np.float64(2.5), np.float64(3.0), np.float64(4.0), np.float64(5.0), np.float64(6.0)]

# %%
plot_stem(df,'devision')

# %%
df['difference'] = df['X1'] - df['X2']
YY_difference = XX1_fine - XX2_fine
plot_contour(XX1,XX2,df,'difference',XX1_fine,XX2_fine,YY_difference)
# Out:
# [np.int64(-5), np.int64(-4), np.int64(-3), np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]

# %%
plot_stem(df,'difference')

# %%
df['abs_difference'] = np.abs(df['X1'] - df['X2'])
YY_abs_difference = np.abs(XX1_fine - XX2_fine)
plot_contour(XX1,XX2,df,'abs_difference',XX1_fine,XX2_fine,YY_abs_difference)
# Out:
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]

# %%
plot_stem(df,'abs_difference')

# %%
df['circle'] = (df['X1'] - 3.5) ** 2 + (df['X2'] - 3.5)**2
YY_circle = (XX1_fine - 3.5) **2 + (XX2_fine - 3.5) **2 
plot_contour(XX1,XX2,df,'circle',XX1_fine,XX2_fine,YY_circle)
# Out:
# [np.float64(0.5), np.float64(2.5), np.float64(4.5), np.float64(6.5), np.float64(8.5), np.float64(12.5)]

# %%
plot_stem(df,'circle')

# %%
import numpy as np

# %%
E_X_2 = 0.007*4.5 + 0.073*4.0 + 0.21*3.5 + 0.49*3.0 + 0.19 * 2.5 + 0.027*2.0

# %%
E_X_2_2 = 0.007*np.square(4.5) + 0.073*np.square(4.0) + 0.21*np.square(3.5) + 0.49*np.square(3.0) + 0.19 * np.square(2.5) + 0.027*np.square(2.0)

# %%
var_X_2 = E_X_2_2 - np.square(E_X_2)

# %%
var_X_2
# Out:
# np.float64(0.2394437499999995)

# %%
var_X_2_st = np.sqrt(var_X_2)
var_X_2_st
# Out:
# np.float64(0.48932989894344237)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris
#链式赋值无法保证df是自身还是副本,可能会警告
pd.options.mode.chained_assignment = None

# %%
X_df = pd.read_pickle('X_df.pkl')

# %%
def heatmap_sum(data,i_array,j_array,title,vmin,vmax,cmap):
    fig,ax = plt.subplots(figsize = (10,10))
    ax = sns.heatmap(data,cmap = cmap,
                     cbar_kws = {'orientation':'horizontal'},
                     yticklabels = i_array,xticklabels = j_array,
                     ax = ax,annot = True,
                     linewidths = 0.25,linecolor = 'grey',
                     vmin = vmin,vmax = vmax
                    )

    ax.set_xlabel('Sepal length')
    ax.set_ylabel('Sepal width')
    ax.set_aspect('equal')
    plt.title(title)
    plt.yticks(rotation = 0)

# %%
X_df.sepal_length = round(X_df.sepal_length * 2) / 2
X_df.sepal_width  = round(X_df.sepal_width  * 2) / 2
#sort英语是排序分类的意思
sepal_length_array = np.sort(X_df.sepal_length.unique())#取唯一值升序
sepal_width_array = -np.sort(-X_df.sepal_width.unique())#取唯一值 取反升序 再取反  总体看是降序

# %%
fig,ax = plt.subplots()
ax = sns.scatterplot(data = X_df,x = 'sepal_length',y = 'sepal_width')

ax.axvline(x=0, c='k') # 添加x轴垂直线
ax.axhline(y=0, c='k') # 添加y轴水平线
ax.set_xlabel('Sepal length, $x_1$ (cm)') # 设置x轴标签
ax.set_ylabel('Sepal width, $x_2$ (cm)') # 设置y轴标签
ax.set_xticks(np.arange(0, 8 + 1, step=0.5)) # 设置x轴刻度
ax.set_yticks(np.arange(0, 6 + 1, step=0.5)) # 设置y轴刻度
ax.axis('scaled') # 设置坐标轴比例
ax.grid(linestyle='--', linewidth=0.25, color=[0.7,0.7,0.7]) # 设置网格样式
#set_xbound可以被覆盖,没有lim那么硬(配置了lim几乎不会变了)
ax.set_xbound(lower=0, upper=8) # 设置x轴范围
ax.set_ybound(lower=0, upper=6) # 设置y轴范围

# %%
#df的[]只接收一个参数,一个还行,多个需要用[]或者()括起来
X_df_12 = X_df[['sepal_length','sepal_width']]
X_df_12['count'] = 1
#生成频率矩阵
#第一次groupby返回一个自己的类型,这个类型可以用count
    #groupby将每一个行作为一组返回自己的类型(进行了分组和去重的操作)
    #这个groupby有count方法返回每一组的记数 这里又变回了df
#继续用unstack变为矩阵
    #unstack是堆叠的意思,level = 0是找每一行的第一个元素作为新的不是堆叠的新矩阵的行索引
    #剩下的自动进行,第二个为列索引,只剩下一个作为值 新的位置有的为Nan(无关联
frequency_matrix = X_df_12.groupby(['sepal_length','sepal_width']).count().unstack(level = 0)
frequency_matrix = frequency_matrix.fillna(0)#填充Nan为0 Nan是缺失的意思,fill是填上的意思
#逆序排列 iloc是df的索引方式,这里只有一个,所以操作行
    #因为之前返回的是升序的
frequency_matrix = frequency_matrix.iloc[::-1] 

probability_matrix = frequency_matrix / 150

# %%
X_df_12['count'] = 1 #添加记数列,这一列都是1 这一步暂时看是多余的,后面count返回的df自带count列

# %%
title = 'No species label,frequency'
heatmap_sum(frequency_matrix,sepal_width_array,sepal_length_array,title,0,50,'plasma_r')

# %%
title = 'No species label,probability'
heatmap_sum(probability_matrix,sepal_width_array,sepal_length_array,title,0,0.4,'viridis_r')

# %%
freq_sepal_length = frequency_matrix.sum(axis = 0).to_numpy().reshape((1,-1))
prob_sepal_length = probability_matrix.sum(axis = 0).to_numpy().reshape((1,-1))

# %%
title = 'Marginal count,frequency,sepal length'
heatmap_sum(freq_sepal_length,[],sepal_length_array,title,0,50,'plasma_r')

# %%
title = 'Marginal count,probability,sepal length'
heatmap_sum(prob_sepal_length,[],sepal_length_array,title,0,0.4,'viridis_r')

# %%
E_X1 = prob_sepal_length @ sepal_length_array.reshape(-1,1)

# %%
E_X1_ = X_df['sepal_length'].mean()

# %%
E_X1_sq = prob_sepal_length @ (sepal_length_array **2 ).reshape(-1,1)

# %%
var_X1 = E_X1_sq - E_X1**2

# %%
var_X1_ = X_df['sepal_length'].var() * 149 / 150 #df的方差默认是n - 1,这里进行修正

# %%
freq_sepal_width = frequency_matrix.sum(axis = 1).to_numpy().reshape(-1,1)

# %%
prob_sepal_width = probability_matrix.sum(axis = 1).to_numpy().reshape(-1,1)

# %%
title = 'Marginal count,frequency,sepal width'
heatmap_sum(freq_sepal_width,sepal_width_array,[],title,0,50,'plasma_r')

# %%
title = 'Marginal count,probability,sepal width'
heatmap_sum(prob_sepal_width,sepal_width_array,[],title,0,0.4,'viridis_r')

# %%
E_X2 = sepal_width_array.reshape(1,-1) @ prob_sepal_width

# %%
E_X2_ = X_df['sepal_width'].mean()

# %%
#假设独立

# %%
title = 'Assumption: independence'
heatmap_sum(prob_sepal_width @ prob_sepal_length,sepal_width_array,sepal_length_array,title,0,0.4,'viridis_r')

# %%
#给定长度的条件概率

# %%
probability_matrix
# Out:
#                  count                                                    \
# sepal_length       4.5       5.0       5.5       6.0       6.5       7.0
# sepal_width
# 4.5           0.000000  0.000000  0.006667  0.000000  0.000000  0.000000
# 4.0           0.000000  0.026667  0.026667  0.006667  0.000000  0.000000
# 3.5           0.013333  0.106667  0.033333  0.013333  0.033333  0.006667
# 3.0           0.053333  0.053333  0.060000  0.086667  0.133333  0.073333
# 2.5           0.006667  0.033333  0.060000  0.046667  0.040000  0.000000
# 2.0           0.000000  0.006667  0.000000  0.020000  0.000000  0.000000
#
#
# sepal_length       7.5       8.0
# sepal_width
# 4.5           0.000000  0.000000
# 4.0           0.006667  0.006667
# 3.5           0.000000  0.000000
# 3.0           0.033333  0.000000
# 2.5           0.006667  0.000000
# 2.0           0.000000  0.000000

# %%
given_sepal_length = 5
#之前已经让matrix的列名换成了数字,这里是列名索引
#['count',given_sepal_length]和['count'][given_sepal_length]
    #不一样,前者一次精确取出,后者两次取出虽然结果一样
prob_given_length = probability_matrix['count',given_sepal_length]

# %%
prob_given_length = prob_given_length / prob_given_length.sum()

# %%
title = 'No species label,probability given sepal length'
heatmap_sum(prob_given_length.to_numpy().reshape(-1,1),
            sepal_width_array.reshape(-1,1),[],title,0,0.4,'viridis_r')

# %%
Given_Y = 'virginica'

fig,ax = plt.subplots()

ax = sns.scatterplot(data = X_df.loc[X_df.species == Given_Y],x = 'sepal_length',y = 'sepal_width')
ax.axvline(x = 0, c = 'k')
ax.axhline(y = 0, c = 'k')

ax.set_xlabel('Sepal length, $x_1$ (cm)')
ax.set_ylabel('Sepal width, $x_2$ (cm)')
ax.set_xticks(np.arange(0, 8 + 1, step=0.5))
ax.set_yticks(np.arange(0, 6 + 1, step=0.5))
ax.axis('scaled')
ax.grid(linestyle='--', linewidth=0.25, color=[0.7,0.7,0.7])
ax.set_xbound(lower = 0, upper = 8)
ax.set_ybound(lower = 0, upper = 6)

# %%
X_df_12_given_Y = X_df[['sepal_length','sepal_width','species']]
X_df_12_given_Y['count'] = 1

# %%
#loc是行列选择器,可以是不同方式提取
#~是取反
X_df_12_given_Y.loc[~(X_df_12_given_Y.species == Given_Y),'count'] = np.nan

# %%
X_df_12_given_Y = X_df_12_given_Y[['sepal_length','sepal_width','count']]

# %%
frequency_matrix_given_Y = X_df_12_given_Y.groupby(['sepal_length','sepal_width']).count().unstack(level = 0)

# %%
frequency_matrix_given_Y.columns = frequency_matrix_given_Y.columns.droplevel(0) # 去除列的多层索引

# %%
frequency_matrix_given_Y = frequency_matrix_given_Y.fillna(0)

# %%
frequency_matrix_given_Y = frequency_matrix_given_Y.iloc[::-1]

# %%
#df默认.sum()是按列求和,得到1D的series 第二次再把series求和
probebility_matrix_given_Y = frequency_matrix_given_Y / frequency_matrix_given_Y.sum().sum()

# %%
title = 'Given Y,probability'
heatmap_sum(probebility_matrix_given_Y,sepal_width_array,sepal_length_array,title,0,0.4,'viridis_r')

# %%
freq_sepal_length_given_Y = frequency_matrix_given_Y.sum(axis = 0).to_numpy().reshape(1,-1)

# %%
title = 'freq_sepal_length_given_Y'
heatmap_sum(freq_sepal_length_given_Y,[],sepal_length_array,title,0,50,'plasma_r')

# %%
prob_sepal_length_given_Y = probability_matrix_given_Y.sum(axis = 0).to_numpy().reshape(1,-1)

# %%
title = 'freq_sepal_length_given_Y'
heatmap_sum(freq_sepal_length_given_Y,[],sepal_length_array,title,0,50,'plasma_r')
